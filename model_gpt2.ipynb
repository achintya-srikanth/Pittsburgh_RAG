# %%
import os
import re

def load_and_preprocess_text(folder_path):
    """Loads and preprocesses text files from a given folder."""
    all_text = ""
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):  # Check if it's a text file
            file_path = os.path.join(folder_path, filename)
            try:
                with open(file_path, "r", encoding="utf-8") as file:
                    text = file.read()

                    # Basic preprocessing (remove extra whitespace, etc.)
                    text = re.sub(r'\s+', ' ', text).strip() #Remove extra whitespace.
                    # Add more preprocessing steps as needed (e.g., removing HTML tags, punctuation)
                    all_text += text + "\n"  # Add a newline between files
            except Exception as e:
                print(f"Error processing {filename}: {e}")
    return all_text

folder_path = r"C:\Users\Lenovo\Downloads\End-to-end-LLM-main\End-to-end-LLM-main\annotations\web_text"
processed_text = load_and_preprocess_text(folder_path)

#Save the combined text to a file.
with open("combined_text.txt", "w", encoding = "utf-8") as outfile:
    outfile.write(processed_text)

print("Text files loaded and preprocessed.")
# Out:
# Text files loaded and preprocessed.

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device
# Out:
# device(type='cuda')

# %%
print(torch.cuda.is_available())  # Should print True if CUDA is available
print(torch.cuda.get_device_name(0)) #prints the name of the cuda device.
# Out:
# True
# NVIDIA GeForce RTX 4050 Laptop GPU

# %%
from transformers import AutoTokenizer, TextDataset, DataCollatorForLanguageModeling, Trainer, TrainingArguments, AutoModelForCausalLM, pipeline

# %%
import os
import re
import torch
from transformers import AutoTokenizer, TextDataset, DataCollatorForLanguageModeling, Trainer, TrainingArguments, AutoModelForCausalLM, pipeline

# 1. Data Loading and Preprocessing
def load_and_preprocess_text(folder_path):
    all_text = ""
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            try:
                with open(file_path, "r", encoding="utf-8") as file:
                    text = file.read()
                    text = re.sub(r'\s+', ' ', text).strip()
                    all_text += text + "\n"
            except Exception as e:
                print(f"Error processing {filename}: {e}")
    return all_text

folder_path = r"C:\Users\Lenovo\Downloads\End-to-end-LLM-main\End-to-end-LLM-main\annotations\web_text"
processed_text = load_and_preprocess_text(folder_path)
with open("combined_text.txt", "w", encoding="utf-8") as outfile:
    outfile.write(processed_text)
print("Text files loaded and preprocessed.")

# 2. Model Training (Fine-tuning)
model_name = "gpt2" 
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

train_dataset = TextDataset(
    tokenizer=tokenizer,
    file_path="combined_text.txt",
    block_size=128,
)

data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

training_args = TrainingArguments(
    output_dir="./results",
    overwrite_output_dir=True,
    num_train_epochs=10,
    per_device_train_batch_size=4,
    save_steps=10_000,
    save_total_limit=2,
)

model = AutoModelForCausalLM.from_pretrained(model_name)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
)

trainer.train()
# Out:
# Text files loaded and preprocessed.
# c:\Users\Lenovo\Downloads\End-to-end-LLM-main\End-to-end-LLM-main\New folder\.venv\Lib\site-packages\transformers\data\datasets\language_modeling.py:53: FutureWarning: This dataset will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/main/examples/pytorch/language-modeling/run_mlm.py
#   warnings.warn(

# %%
# Save the model locally
save_path = "./local_model"
if not os.path.exists(save_path):
    os.makedirs(save_path)

model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)

print("Model saved locally at:", save_path)
# Out:
# Model saved locally at: ./local_model

# %%
import pandas as pd
import re
from transformers import pipeline
import  json

def load_test_data(csv_path):
    try:
        # Assuming there is only one column in your CSV file
        column_names = ['prompt']
        df = pd.read_csv(csv_path, names=column_names, header=None)
        return df
    except Exception as e:
        print(f"Error loading CSV: {e}")

def preprocess_test_data(df, column_name):
    try:
        df[column_name] = df[column_name].apply(lambda x: re.sub(r'\s+', ' ', str(x)).strip())
        return df
    except KeyError:
        print(f"Column '{column_name}' not found in DataFrame.")
        return None

def generate_text(model_name, test_prompts):
    generator = pipeline('text-generation', model=model_name)
    generated_texts = []
    
    for prompt in test_prompts:
        output = generator(prompt, max_length=50, num_return_sequences=1)
        generated_texts.append(output[0]['generated_text'])
    
    return generated_texts

if __name__ == "__main__":
    csv_path = "test_set.csv"
    column_name = 'prompt'
    
    # Load test data
    df = load_test_data(csv_path)
    
    # Check column names
    print("Available column names:", df.columns)
    
    # Preprocess test data
    df = preprocess_test_data(df, column_name)
    
    if df is not None:
        # Generate text
        model_name = "local_model"  # Path to your trained model
        test_prompts = df[column_name].tolist()
        generated_texts = generate_text(model_name, test_prompts)
        a = {}
        for prompt, generated_text in zip(test_prompts, generated_texts):
            a[prompt] = generated_text
            print(f"Prompt: {prompt}")
            print(f"Generated Text: {generated_text}\n")
        with open('data.json', 'w') as file:
            json.dump(a, file, indent=4)
    else:
        print("Preprocessing failed. Please check column names.")
# Out:
# Device set to use cuda:0
# Available column names: Index(['prompt'], dtype='object')
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Prompt: Where is the Family Nature Hike held?
# Generated Text: Where is the Family Nature Hike held? A: The Family Nature Hike is an annual tradition in Pittsburgh where participants run a race through Schenley Park, featuring diverse heats for visitors to enjoy various outdoor adventures. Q: What are the weather
#
# Prompt: Which festival celebrates Latin-American culture in Pittsburgh?
# Generated Text: Which festival celebrates Latin-American culture in Pittsburgh? A: The Pittsburgh Picklesburgh festival, which takes place from September 30 to October 2, 2024, showcases pickle-themed beverages, food, and crafts. Q: What is Pickle Juice
#
# Prompt: What public art project by the Pittsburgh Cultural Trust is named after a sudden meteorological event?
# Generated Text: What public art project by the Pittsburgh Cultural Trust is named after a sudden meteorological event? A: The Pittsburgh Cultural Trust is named after Carnegie Museum of Natural History member Dr. Evgeni St. Pierre (1883-1912) who designed
#
# Prompt: What are some of CMU's traditional mainstays that Spring Carnival celebrates?
# Generated Text: What are some of CMU's traditional mainstays that Spring Carnival celebrates? A: Spring Carnival officially kicks off Spring with performances like Pierogi at Mr. Smalls, Main Street Treat with Mister. British Food Truckers at Molly’s
#
# Prompt: Whose work does the Uncommon Perfection event at CMU highlight?
# Generated Text: Whose work does the Uncommon Perfection event at CMU highlight? A: The event features a "Arsenal of Champions" exhibition featuring high-resolution photos of the teams competing in the European Championship. Q: When did the Carnegie Mellon University Event Center
#
# Prompt: How many suites does PNC Park have?
# Generated Text: How many suites does PNC Park have? A: PNC Park has 2800+ suites, with capacities for 18, 24, and 40+ hotels. Q: For information on discounts and passes, click the Discounts and Passes section.
#
# Prompt: What unique event can you attend at CMNH during 21+ Nights?
# Generated Text: What unique event can you attend at CMNH during 21+ Nights? A: You can attend one of the largest independent festivals in the US, the Pittsburgh Independent Festival, where thousands of artists, vendors, and thousands of attendees participate in creative processions
#
# Prompt: What section of the Payroll Tax regulations defines taxpayer responsibilities?
# Generated Text: What section of the Payroll Tax regulations defines taxpayer responsibilities? A: The section specifically mentions the "duty of care" and "convenience" aspects of the tax, ensuring that taxpayers have an enjoyable and affordable way to pay. Q: How
#
# Prompt: Who named Pittsburgh?
# Generated Text: Who named Pittsburgh? A: Pittsburgh is composed of seven neighborhoods: Allegheny, Monongahela, Allegheny, Monongahela County, and Monongahela Island. Q: What cultural attractions should visitors check out in Pittsburgh? A
#
# Prompt: Which event promotes literacy through a food fair in Pittsburgh?
# Generated Text: Which event promotes literacy through a food fair in Pittsburgh? A: The Food Network of Pennsylvania promotes educational and fun outdoor travel by promoting outdoor living spaces, trails, and outdoor gardening techniques. Q: What kinds of attractions can visitors find in Pittsburgh? A
#
# Prompt: Which Major League Baseball division do the Pittsburgh Pirates play in?
# Generated Text: Which Major League Baseball division do the Pittsburgh Pirates play in? A: Pittsburgh is home to the Pittsburgh Pirates (NFL), Pittsburgh Penguins (NHL), and Pittsburgh Pirates (MLB). Q: What sports teams play in Pittsburgh? A: Pittsburgh hosts
#
# Prompt: Which museum at the Heinz History Center celebrates Pittsburgh's sports legacy?
# Generated Text: Which museum at the Heinz History Center celebrates Pittsburgh's sports legacy? A: The Heinz History Center, which opened in May 2025, celebrates the city's sports legacy through exhibits and interactive exhibits. Q: What resources are available for visitors interested in
#
# Prompt: In what year did PNC Park open?
# Generated Text: In what year did PNC Park open? A: PNC Park opened in 1935. Q: What was the focus of the Orchid and Tropical Gardens project? A: The Orchid and Tropical Gardens project aimed at generating tropical flowers and bons
#
# Prompt: According to the Pittsburgh City Paper's Best Of PGH 2024, where can you find the best African food?
# Generated Text: According to the Pittsburgh City Paper's Best Of PGH 2024, where can you find the best African food? A: You can watch Chef Anthony Bourdain's Kitchen School at Phipps Conservatory, or visit Andy Warhol's Vintage Vintage Home
#
# Prompt: Which festival is known for its cultural crafts and music in Pittsburgh?
# Generated Text: Which festival is known for its cultural crafts and music in Pittsburgh? A: Pittsburgh hosts the annual Picklesburgh Festival, where local farmers craft beers and celebrate pickle-themed events. Q: What is one of the key aspects of Pittsburgh's culinary
#
# Prompt: Who is the Vice President of Ticket Operations for the Pittsburgh Steelers?
# Generated Text: Who is the Vice President of Ticket Operations for the Pittsburgh Steelers? A: The Vice President of Ticket Operations is Dierks Bentley, a veteran of the NFL, Steelers, and NHL teams, who has dedicated his time to the game of sports.
#
# Prompt: What commemorates National Vietnam War Veterans Day on March 29?
# Generated Text: What commemorates National Vietnam War Veterans Day on March 29? A: The annual National War Veterans Day Parade occurs on March 29, 2025, honoring all who served in the U.S. Armed Forces during World War II. Q: What significant event
#
# Prompt: What is the name of the trail connecting Pittsburgh to Washington, D.C.?
# Generated Text: What is the name of the trail connecting Pittsburgh to Washington, D.C.? A: The Pittsburgh Adventurer's Trail is named after the celebrated explorer, Senator John Heinz History Center, and the Pittsburgh Riverhounds, who piloted the last
#
# Prompt: What ballet performance will be at the Byham Theater on May 7, 2025?
# Generated Text: What ballet performance will be at the Byham Theater on May 7, 2025? A: The Byham Theater will perform performances of Ballet Suite A and Ballet Suite B, as well as Broadway productions of original Broadway play. Q: Which concert
#
# Prompt: Which classical concert will the Pittsburgh Symphony Orchestra present from April 25-27, 2025?
# Generated Text: Which classical concert will the Pittsburgh Symphony Orchestra present from April 25-27, 2025? A: The Pittsburgh Symphony Orchestra is performing at PPG Paints Arena on March 28 and 29, 2025. Q: What significant event is happening on Pittsburgh Avenue in
#
# Prompt: According to the Pittsburgh City Paper's Best Of PGH 2024, where can you find the best BBQ?
# Generated Text: According to the Pittsburgh City Paper's Best Of PGH 2024, where can you find the best BBQ? A: You can shop for authentic local food in Downtown Pittsburgh, which includes Uptown, which has great portions and is known for its good
#
# Prompt: What is the role of Teryl Austin in the Pittsburgh Steelers coaching staff?
# Generated Text: What is the role of Teryl Austin in the Pittsburgh Steelers coaching staff? A: Teryl Austin is a veteran, NFL Network veteran, and recently named Pittsburgh's head coach. Q: What kind of atmosphere does Pittsburgh play? A: Pittsburgh is
#
# Prompt: How many home run balls have exited PNC Park?
# Generated Text: How many home run balls have exited PNC Park? A: There was only one home run ball impacted by the bouncing on Saturday, impacting only two players. Q: What is the capacity of Acrisure Stadium? A: Acrisure Stadium
#
# Prompt: Who is the current resident pianist for the Pittsburgh Opera?
# Generated Text: Who is the current resident pianist for the Pittsburgh Opera? A: The current resident is Shane Gillis, best known for his work on the Billie Holiday & The Night Sweats, and he will be performing at PPG Paints Arena on
#
# Prompt: In what year will Pittsburgh host the NFL Draft?
# Generated Text: In what year will Pittsburgh host the NFL Draft? A: Pittsburgh will host the NFL Draft in 2022, taking place in early October. Q: What notable historical figure is referred to as the "Arsenal of Steel" in Pittsburgh? A: Arsenal of
#
# Prompt: What are the general event hours for the Pittsburgh Taco Festival?
# Generated Text: What are the general event hours for the Pittsburgh Taco Festival? A: The general event hours are Monday through Saturday from 9:30 AM to 5:00 PM, including lunch, dinner, and visits from dogs and pet-friendly travel options. Q
#
# Prompt: When are The Latchkey Kids performing live?
# Generated Text: When are The Latchkey Kids performing live? A: The Latchkey Kids are performing live at Stage AE on August 17, 2022. Q: What artists are set to perform at the Pavilion at Star Lake in July 2022? A: Artists
#
# Prompt: Which event includes local artisan and crafts vendors?
# Generated Text: Which event includes local artisan and crafts vendors? A: The annual Craft Beer Festival features local breweries, wineries, and distilleries, all free to participate in. Q: What special event does the Kennywood Craft Beer Festival have? A:
#
# Prompt: What event hosts a celebrity bocce challenge in Pittsburgh?
# Generated Text: What event hosts a celebrity bocce challenge in Pittsburgh? A: The "Show Your Badge" event runs from May 1 to November 27, 2024, where participants can win cash prizes and experience live music and games for a chance to win a free
#
# Prompt: Where will Peter Pan - Theatrical Production be held in 2025?
# Generated Text: Where will Peter Pan - Theatrical Production be held in 2025? A: Theatrical productions will take place in 2026, with a focus on productions including the Star Wars™ film franchise and Mattress Factory films. Q: When will production
#
# Prompt: Who became the only Steelers' player to have his number retired in 1964?
# Generated Text: Who became the only Steelers' player to have his number retired in 1964? A: Billy Rose was the only Steelers' player to have his number retired. Q: Why was Pittsburgh named the No. 1 Brewery in the U.S. for 20
#
# Prompt: In what year did the production of steel begin in Pittsburgh?
# Generated Text: In what year did the production of steel begin in Pittsburgh? A: The production of steel in Pittsburgh began in 1758. Q: What was Pittsburgh producing in the years 1815-1845? A: Pittsburgh was producing large quantities of iron,
#
# Prompt: Who serves as the Pitching Coach for the Pittsburgh Pirates?
# Generated Text: Who serves as the Pitching Coach for the Pittsburgh Pirates? A: Sullivan leads the Pitching Coach for the Pittsburgh Pirates during warmups and games, helping pitchers prepare for a potential game-winning single. Q: How does Sullivan provide guidance to teams
#
# Prompt: Which Pittsburgh event offers three-course fixed-price meal specials?
# Generated Text: Which Pittsburgh event offers three-course fixed-price meal specials? A: Pittsburgh offers three-course fixed-price meals on select dates including weekends from March 15-17, 2025, and holiday weekends from March 16-18, 2025. Q:
#
# Prompt: What artist is coming to the Event Center at Rivers Casino Pittsburgh on March 28, 2025?
# Generated Text: What artist is coming to the Event Center at Rivers Casino Pittsburgh on March 28, 2025? A: Jackson Pollock is a renowned visual artist and author, known for his vibrant artwork and surrealist artwork. Q: What exciting event will take place on
#
# Prompt: Where will the Columbus Blue Jackets event be held on March 21, 2025?
# Generated Text: Where will the Columbus Blue Jackets event be held on March 21, 2025? A: The Cleveland Blue Jackets will be performing at PPG Paints Arena on March 22, 2025, with a date yet to be determined. Q: What major sporting event
#
# Prompt: Which Pittsburgh event includes workshops and educational demonstrations?
# Generated Text: Which Pittsburgh event includes workshops and educational demonstrations? A: Pittsburgh hosts various FallFests, typically taking place in the winter, marking the start of spring in the city. Q: How can visitors learn about Pittsburgh's sports culture through events like the Steelers
#
# Prompt: What is the name of the exhibit that features dinosaurs in the Carnegie Museum of Natural History?
# Generated Text: What is the name of the exhibit that features dinosaurs in the Carnegie Museum of Natural History? A: The exhibit "Dinosaur: The Unconventional Life Picture" features a 20-second facsimile of a manilingay dinosaur, covered with
#
# Prompt: What festival in Pittsburgh involves candy bar bingo and face painting?
# Generated Text: What festival in Pittsburgh involves candy bar bingo and face painting? A: The Pittsburgh Haunted Paintball & Maze, held from September 15-18, 2024, celebrates Pittsburgh's rich tradition in street art, where participants take amazing picture opportunities along the city
#
# Prompt: What is the reprint fee per ticket for Cultural Trust event tickets?
# Generated Text: What is the reprint fee per ticket for Cultural Trust event tickets? A: The reprint fee is $0.50 for a single ticket, $5.50 for a two-way ticket, and $20.50 for multiple tickets. Q:
#
# Prompt: Who were the founders of Carnegie Mellon University?
# Generated Text: Who were the founders of Carnegie Mellon University? A: The founders of Carnegie Mellon University were Duquesne Inclineurs, John Muir and Albert Einstein. Q: What are some of the world-class institutions founded in the United States?
#
# Prompt: Which Pittsburgh event is scheduled for July 18-21, 2024?
# Generated Text: Which Pittsburgh event is scheduled for July 18-21, 2024? A: Pittsburgh will host the NFL Draft in Pittsburgh on July 18-21, 2024. Q: When will the St. Patrick's Day Parade in Pittsburgh take place in 2024? A
#
# Prompt: Which GRAMMY nominee is featured in Child of God Tour Part 2?
# Generated Text: Which GRAMMY nominee is featured in Child of God Tour Part 2? A: In the film, he is referred to simply as "Miguel" and mentions performing in films like "Miguel Muñoz Incline." Q
#
# Prompt: In which Pittsburgh museum can you find a variety of Smithsonian objects?
# Generated Text: In which Pittsburgh museum can you find a variety of Smithsonian objects? A: You can visit the Carnegie Museums of Art and Natural History in Pittsburgh, enjoy interactive exhibits such as an interactive view of the University of Pittsburgh skyline, and enjoy pet-friendly
#
# Prompt: When will Picklesburgh 2024 be held?
# Generated Text: When will Picklesburgh 2024 be held? A: Picklesburgh 2024 will take place in 2024, with a specific focus on hotels, resorts, and the transportation of kids. Q: What kind of interactive experiences are planned at Picklesburgh?
#
# Prompt: Which concert at Heinz Hall on April 7, 2025, celebrates boy bands?
# Generated Text: Which concert at Heinz Hall on April 7, 2025, celebrates boy bands? A: The concert, "Love Rocks: A Musical Anthology," features a ballad set against the vibrant music in the city, featuring covers by U2, The
#
# Prompt: What sport is the Pittsburgh Vintage Grand Prix held annually at Schenley Park?
# Generated Text: What sport is the Pittsburgh Vintage Grand Prix held annually at Schenley Park? A: The Pittsburgh Vintage Grand Prix is held annually and features a track from November 15 to December 17, 2024, featuring the Pittsburgh International Raceway and Chrysler Pacific Fairway
#
# Prompt: Which festival will be celebrated in Latrobe, PA in 2025?
# Generated Text: Which festival will be celebrated in Latrobe, PA in 2025? A: The 2026 NFL Draft is scheduled for April 23-25, 2026. Q: What is the focus of the Big Nosh Jewish Food Festival? A: The Big
#
# Prompt: What is the theme of the events during Super Science Saturdays at CMNH?
# Generated Text: What is the theme of the events during Super Science Saturdays at CMNH? A: The theme is "Mental Health: Mind Matters: Mind Matters: Mind Matters: Mind Matters: Mind Matters: Mind Matters" and it features a talk by renowned
#
# Prompt: Which food event celebrates Jewish and Israeli food culture in Pittsburgh?
# Generated Text: Which food event celebrates Jewish and Israeli food culture in Pittsburgh? A: The Pittsburgh Jewish Food Festival, held from September 6-8, 2024, celebrates Jewish and Israeli food cultures, featuring traditional, strictly kosher dishes prepared by culinary experts. Q: By
#
# Prompt: Which food is celebrated in Pittsburgh in August?
# Generated Text: Which food is celebrated in Pittsburgh in August? A: Pittsburgh’s August food festivals take place, marking the end of August in Pittsburgh with festivities and festivals celebrating all things seafood. Q: What unique month in Pittsburgh is celebrated for Pittsburgh-based
#
# Prompt: What is the price for a single VIP Experience at Little Italy Days?
# Generated Text: What is the price for a single VIP Experience at Little Italy Days? A: The price includes admission to both Days, a themed pass for kids, and a code for a special drink at the Daniel G. and Carole L. Kamin Science
#
# Prompt: Who is the concertmaster of the Pittsburgh Symphony Orchestra?
# Generated Text: Who is the concertmaster of the Pittsburgh Symphony Orchestra? A: The concertmaster of the Pittsburgh Symphony Orchestra is Gordo Grist, known for expertly performing orchestras like the violinist Daniel Kahnam and for fine jazz music like I'll Be
#
# Prompt: What is the Heinz History Center’s affiliation with a national institution?
# Generated Text: What is the Heinz History Center’s affiliation with a national institution? A: The Heinz History Center is an officially recognized national organization that serves as an historical resource for the region and provides educational opportunities and information to enhance regional awareness and understanding
#
# Prompt: What is the nickname for the defensive line of the Pittsburgh Steelers from 1971 to 1981?
# Generated Text: What is the nickname for the defensive line of the Pittsburgh Steelers from 1971 to 1981? A: The defensive line refers to any part of the Steelers' body that is covered with thick, thick, thick, and almost black steel bars, commonly referred to
#
# Prompt: Which organizations benefit from the proceeds of the Pittsburgh Taco Festival?
# Generated Text: Which organizations benefit from the proceeds of the Pittsburgh Taco Festival? A: The Pittsburgh Taco Festival, which distributes beer and wine to businesses, supports local initiatives and promotes a healthier community through creative culinary experiences. Q: What are some of the top rated
#
# Prompt: Who donated to the City of Pittsburgh for the construction of the Phipps Conservatory and Botanical Gardens?
# Generated Text: Who donated to the City of Pittsburgh for the construction of the Phipps Conservatory and Botanical Gardens? A: The funds raised through this film will also go towards the purchase of an EQ-6000 television set from Harmony Q, as well as
#
# Prompt: When is Brewhaha happening?
# Generated Text: When is Brewhaha happening? A: Brewhaha takes place on March 14, 2024, and it features live music and a scavenger hunt as the title suggests. Q: What is unique about the way the title suggests DICK'S
#
# Prompt: What memoir is CMU's Center for Student Diversity & Inclusion discussing on March 24, 2025?
# Generated Text: What memoir is CMU's Center for Student Diversity & Inclusion discussing on March 24, 2025? A: The Center for Student Diversity & Inclusion is a four-day event celebrating the arrival of students from diverse colleges and universities. Q: What
#
# Prompt: When was Pittsburgh declared a city?
# Generated Text: When was Pittsburgh declared a city? A: Pittsburgh was declared a city on April 15, 1758. Q: Which states are officially in Pennsylvania? A: Pennsylvania is called Pennastia, after the Greek city of Miletos. Q:
#
# Prompt: Who is the director of the Carnegie Mellon Guitar Ensemble on April 16, 2025?
# Generated Text: Who is the director of the Carnegie Mellon Guitar Ensemble on April 16, 2025? A: The director of the Carnegie Mellon Guitar Ensemble is Bill Shankel, known for creating a unique and powerful tone across the Carnegie Mellon campus. Q: Are
#
# Prompt: Which festival offers a pie-eating contest as an activity?
# Generated Text: Which festival offers a pie-eating contest as an activity? A: Yes, The Big Nosh Jewish Food Festival features high-energy, vegan and vegetarian dishes, live music, and dishes from Pittsburgh's best independent restaurants, catering to various interests,
#
# Prompt: When does Pittsburgh Moon Markets Butler City take place?
# Generated Text: When does Pittsburgh Moon Markets Butler City take place? A: Pittsburgh Moon Markets Butler City takes place on Sundays from April 8 to April 15, 2024, from 9 a.m. to 5 p.m. and is open on Fridays and Sundays at
#
# Prompt: What types of contests are included in the Olympickle Games?
# Generated Text: What types of contests are included in the Olympickle Games? A: The Olympleagues Run and Walk include all four seasons including snowmobiling, incline cycling, triathlons, and walking. Q: What activities are included in the
#
# Prompt: What special activity does the Warhol Museum offer every Friday through Sunday for kids and families?
# Generated Text: What special activity does the Warhol Museum offer every Friday through Sunday for kids and families? A: The Warhol Museum offers a variety of activities including exhibits, ghost stories, and public performances like the Haunted Pittsburgh Ghost Show at ScareHouse, where kids
#
# Prompt: When is the Winter Pittsburgh Restaurant Week in 2024?
# Generated Text: When is the Winter Pittsburgh Restaurant Week in 2024? A: The Winter Pittsburgh Restaurant Week is held from November 22nd to December 24th, 2024, featuring local restaurants and shops running from November 22nd to December 25th. Q: What is the
#
# Prompt: Which section of the Parking Tax regulations covers record-keeping?
# Generated Text: Which section of the Parking Tax regulations covers record-keeping? A: The section does not mention proper parking spots, so it is advisable to check with your local transportation authority for the proper parking availability. Q: What is the name of the event listed
#
# Prompt: What is the name of the Pittsburgh neighborhood that was once a major industrial area?
# Generated Text: What is the name of the Pittsburgh neighborhood that was once a major industrial area? A: The neighborhood was known as the "Yinzer Coughlin Reserve," and it has a distinct African American flavor. Q: What neighborhoods in Pittsburgh offer great
#
# Prompt: What comedian and actor is coming to Pittsburgh improv on March 26, 2025?
# Generated Text: What comedian and actor is coming to Pittsburgh improv on March 26, 2025? A: Andy Warhol will be performing at Stage AE on March 27, 2025, during which time he will not be performing. Q: What is the March Against Paging
#
# Prompt: Where does the Pittsburgh Symphony Orchestra perform?
# Generated Text: Where does the Pittsburgh Symphony Orchestra perform? A: The Pittsburgh Symphony Orchestra is a nationally celebrated classical orchestra, with hundreds of musicians performing weekly. Q: What is the focus of the Pittsburgh Symphony Orchestra? A: The Pittsburgh Symphony Orchestra is renowned for its
#
# Prompt: What is the official dessert of Pennsylvania?
# Generated Text: What is the official dessert of Pennsylvania? A: The official dessert of Pennsylvania is Pusadee's Creamery, located in Heinz Hall Courtyard, located at 4054 Airport St., Pittsburgh, Pennsylvania 15212. Q: What special treat
#
# Prompt: In which year was the Pittsburgh Pirates baseball team established?
# Generated Text: In which year was the Pittsburgh Pirates baseball team established? A: Pittsburgh was established in 1758. Q: Describe the typical organization characteristics of the Pittsburgh Pirates organization. A: The Pittsburgh Pirates are composed of two strong and defensively-minded teams,
#
# Prompt: Who drafted Mario Lemieux in 1984?
# Generated Text: Who drafted Mario Lemieux in 1984? A: Both drafted Pittsburgh first baseman Mario Lemieux. Q: Which two players were named to theros in the 1950s and 1960s? A: Both were named to theros in the 1970
#
# Prompt: Who wrote the CMU drama "The Inseparables"?
# Generated Text: Who wrote the CMU drama "The Inseparables"? A: Joseph Campbell is best known for his role as Campbell in the celebrated television show "The Butler" and for writing the Campbell’s Children’s Playbook. Q:
#
# Prompt: What kind of food is primarily featured at the Pittsburgh Taco Festival?
# Generated Text: What kind of food is primarily featured at the Pittsburgh Taco Festival? A: The Pittsburgh Taco Festival features a variety of local, national, and international food trucks curating a memorable food experience throughout the week in 2024. Q: What term is used to
#
# Prompt: What is the primary enforcement agency for tax violations in Pittsburgh?
# Generated Text: What is the primary enforcement agency for tax violations in Pittsburgh? A: The Primary Enforcement Agency for Tax Violations is The Business Services Division, which is composed of 10 employees and is charged with enforcing Pennsylvania's tax laws. Q: What types of activities
#
# Prompt: Where is the 2025 National Dance Championships hosted?
# Generated Text: Where is the 2025 National Dance Championships hosted? A: The 2025 National Dance Championships are held in Pittsburgh on January 12, 2025. Q: What are some of the top performing American sports teams in Pittsburgh? A: Top performing American sports teams include the
#
# Prompt: Who will be moderating the CMU event the CMU event "Spaces of Treblinka"?
# Generated Text: Who will be moderating the CMU event the CMU event "Spaces of Treblinka"? A: Andrei Lankov and Andrei Ahtesaki will be joining the group as moderators. Q: When will the David L.
#
# Prompt: What event signifies the start of NFL season for the Steelers?
# Generated Text: What event signifies the start of NFL season for the Steelers? A: Pittsburgh will host the Pittsburgh Steelers NFL Draft in early October. Q: What are the seating capacities at Heinz Hall? A: Pittsburgh has more than 60,000 seats for the
#
# Prompt: What story-based activity will be held at the museum on March 15, 2025, for kids and families?
# Generated Text: What story-based activity will be held at the museum on March 15, 2025, for kids and families? A: The museum will host a STEM themed scavenger hunt on March 15, 2025, where kids can challenge friends to 1,000 free
#
# Prompt: Who was the first African-American head coach of the Pittsburgh Steelers, starting in 2007?
# Generated Text: Who was the first African-American head coach of the Pittsburgh Steelers, starting in 2007? A: Jim Schwartz served as the team's head coach from August 2, 2007, through August 5, 2009. Q: What type of sports memorabilia can
#
# Prompt: When was the CMU Buggy Alumni Association founded?
# Generated Text: When was the CMU Buggy Alumni Association founded? A: The CMU Buggy Alumni Association was founded in 1935. Q: When was the first Gulf War Illusions Conference held? A: The first Gulf War Illusions Conference was
#
# Prompt: Which mascot was introduced by the Steelers in their 2007 season?
# Generated Text: Which mascot was introduced by the Steelers in their 2007 season? A: The Pittsburgh Steeler is a 5'11" Giant Cat that was featured in the season-opener and won the Youth Award at the Dick's Sporting Goods Pittsburgh Marathon in August
#
# Prompt: Who are the Spring 2024 Spring Carnival chairs?
# Generated Text: Who are the Spring 2024 Spring Carnival chairs? A: The Spring 2024 Spring Carnival chairs will be Jason and Rosemary Trotterboom and Willa Lomas, running from the Pavilion at Morristown and Westmoreland Streets. The seats
#
# Prompt: When did Buggy begin at the CMU Spring Carnival?
# Generated Text: When did Buggy begin at the CMU Spring Carnival? A: Buggy began at the CMU Spring Carnival in late October of 1990. Q: What is the theme for the Kennywood Party in Pittsburgh from November 22 to December 24? A
#
# Prompt: Which league do the Pittsburgh Penguins belong to?
# Generated Text: Which league do the Pittsburgh Penguins belong to? A: The Pittsburgh Penguins play in the Champions League, with an 8-team league based in Pittsburgh called the Pittsburgh Penguins. Q: Which teams are the Pittsburgh Penguins based in Pittsburgh? A: The Pittsburgh
#
# Prompt: What quirky food items can you find at Picklesburgh?
# Generated Text: What quirky food items can you find at Picklesburgh? A: Picklesburgh features a wide selection of pickle-themed items, including pickle-themed decorations, signature wings, and even a Picklesburgh Cookie! Q: What are
#
# Prompt: Who is the current leader of the Pittsburgh Opera?
# Generated Text: Who is the current leader of the Pittsburgh Opera? A: William Pitt is the current leader of the Pittsburgh Opera. Q: What achievements have the Pittsburgh Opera made in the past decade? A: The Pittsburgh Opera has made a significant contribution to the music
#
# Prompt: When is One Big Table scheduled in 2024?
# Generated Text: When is One Big Table scheduled in 2024? A: One Big Table is scheduled for June 23-25, 2024. Q: Are there any new restaurants or places planned for 2024 in Pittsburgh? A: Yes, there are new restaurants or places planned
#
# Prompt: In what year did the University of Pittsburgh's precursor, the Pittsburgh Academy, receive its charter?
# Generated Text: In what year did the University of Pittsburgh's precursor, the Pittsburgh Academy, receive its charter? A: The Pittsburgh Academy of Sciences was established in 1794. Q: Since then, the University of Pittsburgh has received a series of national and international honors
#
# Prompt: What CMU drama will be hosted on April 23, 2025?
# Generated Text: What CMU drama will be hosted on April 23, 2025? A: CMU will present a variety of CMU-produced films, including the 2024–25 School Year Film Series, as part of its Spring Tour. Q: What significant event
#
# Prompt: What is the role of the Department of Finance in Pittsburgh?
# Generated Text: What is the role of the Department of Finance in Pittsburgh? A: The DFO is responsible for managing the finances of the Pittsburgh financial system, providing assistance to help individuals and businesses meet their financial needs. Q: What unique feature does Pittsburgh have regarding
#
# Prompt: What is the current stadium of the Pittsburgh Pirates?
# Generated Text: What is the current stadium of the Pittsburgh Pirates? A: The Pittsburgh Pirates play baseball at PNC Park, home of the Pittsburgh Pirates. Q: What notable event is going on in Pittsburgh this week? A: Pittsburgh is celebrating its 150th birthday
#
# Prompt: When is the Puzzling Adventures Scavenger Hunt happening?
# Generated Text: When is the Puzzling Adventures Scavenger Hunt happening? A: The Puzzling Adventures Scavenger Hunt is a weekend event from September 27 to October 3, 2024, where attendees can experience the Pittsburgh's first full-scale Scavenger Hunt
#
# Prompt: What is the operating hours of the Old Allegheny County Jail Museum?
# Generated Text: What is the operating hours of the Old Allegheny County Jail Museum? A: The Jail Museum is open 365 days a year, running approximately every 5 minutes. It is open Monday to Thursday from 9:30 AM to 5:00 PM, Friday
#
# Prompt: What celebrates the joy of girlhood during a multigenerational celebration of storytelling and history?
# Generated Text: What celebrates the joy of girlhood during a multigenerational celebration of storytelling and history? A: Greer Kline at GreerKline is a celebrated cultural anthropologist and author, who shares her love of science with her students and guides
#
# Prompt: What position does Tarrik Brock coach for the Pittsburgh Pirates?
# Generated Text: What position does Tarrik Brock coach for the Pittsburgh Pirates? A: Tarrik is a veteran of the NFL Draft and is the head coach of the Pittsburgh's Football Players Association (NFLPA). Q: What is the significance of the bridges in Pittsburgh
#
# Prompt: Where can Steelers fans trade their game tickets?
# Generated Text: Where can Steelers fans trade their game tickets? A: Fans can trade their tickets for games at nearby bars, restaurants, shops, and outdoor attractions like concerts, farmers markets, and baseball games. Q: Is there support for specific transportation options in Pittsburgh
#
# Prompt: What family-friendly concert will be held at Heinz Hall on April 5, 2025?
# Generated Text: What family-friendly concert will be held at Heinz Hall on April 5, 2025? A: The Heinz Hall Block Party will take place on April 5, 2025, featuring various Broadway and musical performances including "What Is Magic for You?" by
#
# Prompt: What are the dates for Little Italy Days in 2024?
# Generated Text: What are the dates for Little Italy Days in 2024? A: The dates for Little Italy Days in 2024 are as follows:
# TUESDAY, April 4, 2024: Activities include demonstrations, picnicking, strolling violinists, live performances
#
# Prompt: What are PNC Park's ticket office hours on weekdays?
# Generated Text: What are PNC Park's ticket office hours on weekdays? A: Tickets for PNC Park go on sale on Tuesday (closed on weekends), Thursday (closed on Saturdays) and Friday (closed on Sundays), with details to be announced in the
#
# Prompt: When do doors open before performances for concerts at the Pittsburgh Symphony for classical concerts?
# Generated Text: When do doors open before performances for concerts at the Pittsburgh Symphony for classical concerts? A: Doors open at 9 a.m. and close at midnight. Q: What concert activities are planned for July 14, 2024, at PPG Paints Arena
#
# Prompt: What event will take place at the Bitz Opera Factory at 9:00 PM on April 29, 2025?
# Generated Text: What event will take place at the Bitz Opera Factory at 9:00 PM on April 29, 2025? A: The Bitz Opera Factory is a new production house that will be opening at Andy Warhol's Factory on April 24, 2025.
#
# Prompt: When does Steelers training camp usually start?
# Generated Text: When does Steelers training camp usually start? A: Steelers training camp starts in August and runs through September, with numerous events listed in upcoming weeks.
# Q: What major sporting event will Pittsburgh host in 2026? A: Pittsburgh will host the NFL
#
# Prompt: What are the official team colors of the Pittsburgh Steelers?
# Generated Text: What are the official team colors of the Pittsburgh Steelers? A: The official team colors of the Pittsburgh Steelers are designed to celebrate the city's rich history and tradition of diversity, ensuring a vibrant team look. Q: What is the significance of the year
#
# Prompt: What number can you call to purchase Cultural Trust event tickets?
# Generated Text: What number can you call to purchase Cultural Trust event tickets? A: The Pittsburgh Regional Transit Bus Company is number 528-BUFFT. Q: When is the Pittsburgh Regional Transit Bus Company located? A: The Pittsburgh Regional Transit Bus Company is
#
# Prompt: Who led the Pittsburgh Pirates to three straight pennants at the turn of the 20th century?
# Generated Text: Who led the Pittsburgh Pirates to three straight pennants at the turn of the 20th century? A: They had been leading the league in home run capacity for several decades before Plowshares were introduced. Q: Which two Pittsburgh mayors were known
#
# Prompt: Where is the Fort Pitt Museum located?
# Generated Text: Where is the Fort Pitt Museum located? A: The Fort Pitt Museum is located at 1197 W. Carson St., Pittsburgh, Pennsylvania 15212. Q: What can visitors do while in Pittsburgh for the Star Festival? A: Visitors can attend the
#
# Prompt: Where can you get a free five-minute chair massage on the last Friday of every month at CMU?
# Generated Text: Where can you get a free five-minute chair massage on the last Friday of every month at CMU? A: You can get a free five-minute massage at CMU Health System at any time of the day and night, 7am-
#
# Prompt: What is the name of the stadium where the Pittsburgh Pirates play their home games since 2001?
# Generated Text: What is the name of the stadium where the Pittsburgh Pirates play their home games since 2001? A: The venue is located at 115 Federal St., Pittsburgh, Pennsylvania 15212. Q: What notable feature has the Pittsburgh Steelers played in recent years? A
#
# Prompt: How many people voted in the Pittsburgh City Paper’s Best Of PGH Readers’ Poll?
# Generated Text: How many people voted in the Pittsburgh City Paper’s Best Of PGH Readers’ Poll? A: There was only one person chosen to be the text's lead author, with Mr. Chatham serving as the only other person selected.
#
# Prompt: Until what date does the exhibit "The Stories We Keep: Conserving Objects from Ancient Egypt" run at CMNH?
# Generated Text: Until what date does the exhibit "The Stories We Keep: Conserving Objects from Ancient Egypt" run at CMNH? A: The stories themselves will be posted online on May 19, 2024, showcasing over 700 items from more than 40 years of collections
#
# Prompt: Who is the assistant librarian of the Pittsburgh Symphony Orchestra
# Generated Text: Who is the assistant librarian of the Pittsburgh Symphony Orchestra? A: The assistant librarian of the Pittsburgh Symphony Orchestra is Caroline Miller-Barstow, who is known for her ability to keep updated on Symphony performances and concerts on-site. Q
#
# Prompt: What is represented by the NHL Shield?
# Generated Text: What is represented by the NHL Shield? A: The NHL Shield is a piece of technology that protects the Health and Wellness Center from entry and contact during games, providing a protective coating to assist in the protection of the team during the inevitable head-
#
# Prompt: When is the Pittsburgh Irish Festival held in 2024?
# Generated Text: When is the Pittsburgh Irish Festival held in 2024? A: The Pittsburgh Irish Festival is held in 2024, showcasing local food trucks, connoisseurs, and experimental food trucks in a variety of creative ways. Q: What is the focus of the
#
# Prompt: What is the purpose of the Five-Year Financial Forecast?
# Generated Text: What is the purpose of the Five-Year Financial Forecast? A: The five-year financial forecast includes significant market and economic developments that will positively affect Pittsburgh, including significant job growth, tax revenues, and overall economic activity. Q: What is
#
# Prompt: Who is responsible for tax audits in Pittsburgh?
# Generated Text: Who is responsible for tax audits in Pittsburgh? A: The Auditor General of Pennsylvania is the person who issues tax audits, rather than the government. Q: What annual reports are submitted to the Ohio Division of Revenue on behalf of the Ohio government? A
#
# Prompt: Which exhibition celebrates 45 years of CAPA with works by alumni and faculty?
# Generated Text: Which exhibition celebrates 45 years of CAPA with works by alumni and faculty? A: The exhibition "45 Years of American Music," which opened at the Carnegie Museum of Art on March 16, features hundreds of original prints, covers, and other artworks
#
# Prompt: Which exhibition at 820 Gallery showcases the work of Melike Konur?
# Generated Text: Which exhibition at 820 Gallery showcases the work of Melike Konur? A: The exhibition "Mental Health: Mind Matters" is set to take place on March 14, featuring immersive demos and personal stories about mental health. Q: What is the
#
# Prompt: What is the official email address for the Pittsburgh Taco Festival?
# Generated Text: What is the official email address for the Pittsburgh Taco Festival? A: The official email address for the Pittsburgh Taco Festival is 412-224-4427. Q: What should I do if I have questions while planning my trip to Pittsburgh? A:
#
# Prompt: What is the name of the stadium where the Pittsburgh Pirates have played their home games since 2001?
# Generated Text: What is the name of the stadium where the Pittsburgh Pirates have played their home games since 2001? A: The stadium is called the Pittsburgh Stadium and is located at 115 Federal St., Pittsburgh, Pennsylvania 15212. Q: What nickname was given to the
#
# Prompt: Where is the 2025 Night Nation Run held?
# Generated Text: Where is the 2025 Night Nation Run held? A: The 2026 Night Nation Run takes place on October 26 and 27, 2025, celebrating Black and Latino artists, athletes, and the city of Pittsburgh. Q: Can attendees participate in the FedEx Pittsburgh
#
# Prompt: What food will be provided at Playtest Night at CMU on March 25, 2025?
# Generated Text: What food will be provided at Playtest Night at CMU on March 25, 2025? A: Playtest Night will be provided by CMU Food Lab, with assistance from Pittsburgh Veg Food Lab. Q: What type of entertainment is offered at the
#
# Prompt: Which document governs the collection of unpaid taxes in Pittsburgh?
# Generated Text: Which document governs the collection of unpaid taxes in Pittsburgh? A: The "U.S. Federal Income Tax Compliance Act of 1978" includes several sections specifically for tax avoidance activities in Pennsylvania. Q: Can I correct inaccuracies in my information provided on
#
# Prompt: What type of objects does the new exhibit "The Stories We Keep" at the CMNH focus on?
# Generated Text: What type of objects does the new exhibit "The Stories We Keep" at the CMNH focus on? A: The new exhibit, "The Stories We Keep: An Anthology of Imagery & Community," features 10 minutes of new footage from inside
#
# Prompt: What is the word mark image related to that is mentioned as a registered trademark?
# Generated Text: What is the word mark image related to that is mentioned as a registered trademark? A: The term is used to describe any display, print, or other digital media that identifies or suggests the user's race, color, religion, age, or other
#
# Prompt: Which website provides official merchandises like jerseys and hats for the Steelers?
# Generated Text: Which website provides official merchandises like jerseys and hats for the Steelers? A: The Official Pittsburgh Steelers T-Shirt Factory is located at 300 North Shore Dr., Pittsburgh, Pennsylvania 15212. Q: What activities does the Pittsburgh Steelers pride themselves
#
# Prompt: What comedy show will be at the Byham Theater on May 9, 2025?
# Generated Text: What comedy show will be at the Byham Theater on May 9, 2025? A: The Byham Theater will host a Comedy Central Live Show featuring various sketches and performances, including a sketch comedy special featuring Jimmy Fallon. Q: Will there be any
#
# Prompt: What was the name of the rebellion against federal taxes on whiskey in Western Pennsylvania?
# Generated Text: What was the name of the rebellion against federal taxes on whiskey in Western Pennsylvania? A: The rebellion began in 1794 as a result of widespread strikes and strikes by farmers against the established order. Q: What was a major consequence of Prohibition in Pittsburgh
#
# Prompt: What year was Pittsburgh founded?
# Generated Text: What year was Pittsburgh founded? A: Pittsburgh founded in 1758. Q: Which notable individuals were leaders in the steel industry during the Pittsburgh steel boom? A: Robert Lloyd Wright was a renowned industrialist and founder of the Wright Brothers, producing for
#
# Prompt: What skills can you learn at the Fix-it Fair at CMU on March 20, 2025?
# Generated Text: What skills can you learn at the Fix-it Fair at CMU on March 20, 2025? A: You can learn to code, gather information, and operate a Mac, all in just a few hours.
# Q: What are some tips
#
# Prompt: What is the title of the opera featuring a stolen Lucien Freud painting and multiple possible endings?
# Generated Text: What is the title of the opera featuring a stolen Lucien Freud painting and multiple possible endings? A: The play, titled "Miguel Muñoz in French" starts with a monologue by Muñoz in which he is reb
#
# Prompt: Which month hosts the annual Fish Fry Season in Pittsburgh?
# Generated Text: Which month hosts the annual Fish Fry Season in Pittsburgh? A: Tickets for the annual Fish Fry In Pittsburgh go on sale on August 25, 2024, starting at $22.95. Q: What special activities is expected from the Pittsburgh Botanic Garden
#
# Prompt: What nickname is derived from "buccaneer" and commonly used for the Pittsburgh Pirates?
# Generated Text: What nickname is derived from "buccaneer" and commonly used for the Pittsburgh Pirates? A: Bunteer is an Old English name for someone with whom English is not very formal and uses a more formal Latin name. Q: Why is
#
# Prompt: Where does the Pittsburgh Opera perform?
# Generated Text: Where does the Pittsburgh Opera perform? A: The Pittsburgh Opera plays host to many top-notch performances year-round, including the Carnegie Museum of Art's Winter Concert Series, the Carnegie Symphony Orchestra's Winter Concert Series, and the James Beard Award
#
# Prompt: What is the central theme of the Big Nosh Festival?
# Generated Text: What is the central theme of the Big Nosh Festival? A: The Big Nosh Festival features traditional, family-friendly food, where kids participate in creative outdoor culinary challenges alongside traditional meat-eating locals. Q: When does the Kennywood Holiday
#
# Prompt: What is the name of the Pittsburgh airport?
# Generated Text: What is the name of the Pittsburgh airport? A: The Pittsburgh Airport is the home of Air Transport Pittsburgh, the nation’s first multi-stop airport, dedicated to generating business and travel experience for the local economy.
# Q: What recognition
#
# Prompt: What year did the Pittsburgh Zoo & PPG Aquarium originally open?
# Generated Text: What year did the Pittsburgh Zoo & PPG Aquarium originally open? A: The Pittsburgh Zoo & PPG Aquarium opened in 1935. Q: What is its general membership—a mix of zoo veterans, connoisseurs, and svel
#
# Prompt: What is the title of the book to be released by M. C. Benner Dixon on April 12, 2025?
# Generated Text: What is the title of the book to be released by M. C. Benner Dixon on April 12, 2025? A: The title of the book is titled, Demolition: How to Deal with Disasters, Part 1: A Primer
#
# Prompt: What is the largest expenditure under the 2024 operating budget?
# Generated Text: What is the largest expenditure under the 2024 operating budget? A: The largest expenditure under the 2024 operating budget was $2.58 billion, for health care services, education, and technology. Q: Who can I learn more about underrepresented minorities in
#
# Prompt: When is the Great American Banana Split Celebration in 2025?
# Generated Text: When is the Great American Banana Split Celebration in 2025? A: The Great American Banana Split Celebration takes place annually and features a live music event featuring local vendors and friends from across the city. Q: What unique festival takes place in Pittsburgh during the holiday
#
# Prompt: What food fair will showcase 20+ restaurants with global cuisine?
# Generated Text: What food fair will showcase 20+ restaurants with global cuisine? A: The 20+ Food Co-op Food Fest at Phipps Conservatory aims to present unique ideas and experiences in welcoming new chefs to the city. Q: What emerging food scene
#
# Prompt: What is the name of the stadium where the Pittsburgh Steelers play?
# Generated Text: What is the name of the stadium where the Pittsburgh Steelers play? A: The Steelers facility is located on Federal Avenue in Pittsburgh's North Shore, County. Q: What features does the Heinz History Center have? A: The Heinz History Center
#
# Prompt: What type of guide is available for potential visitors to help them plan a trip to Fallingwater?
# ...
# Generated Text: Which department is responsible for city planning in Pittsburgh? A: The city is responsible for the implementation of policies and procedures consistent with Federal, State, and local laws, including the Fair Housing Act, which requires developers to disclose their development plans in advance.
#
# Prompt: What is the address of PNC Park?
# Generated Text: What is the address of PNC Park? A: PNC Park is located at 1195 W. Carson St., Pittsburgh, Pennsylvania 15212. Q: Where can I find the phone number for VisitPITTSBURGH? A: The
#
# Prompt: Which former steel town was mentioned as having faced significant unemployment due to industrial decline?
# Generated Text: Which former steel town was mentioned as having faced significant unemployment due to industrial decline? A: The town was highlighted in Lonely Planet’s 2025 Global Best in Travel list, which mentions the area as a possible future hub for steel. Q: How
#
# Prompt: What Pittsburgh festival features maple syrup tasting?
# Generated Text: What Pittsburgh festival features maple syrup tasting? A: The Picklesburgh festival features maple syrup-sourced beers, live music, and various food offerings, all aimed at exploring different aspects of the region's heritage. Q: What is Craft Beer School
#
# Prompt: When is the Maple Festivals season in Pittsburgh?
# Generated Text: When is the Maple Festivals season in Pittsburgh? A: The Maple Festivals are held in May and June, allowing kids to enjoy various seasonal activities including family fun, arts and culture, shopping, and crafts. Q: What is the best time
#
# Prompt: Who is the General Manager of the Pittsburgh Steelers?
# Generated Text: Who is the General Manager of the Pittsburgh Steelers? A: The General Manager of the Pittsburgh Steelers is William Penn Kuhn, a veteran of the NFL and basketball leagues, who has been instrumental in generating significant league sports history for the Steelers. Q:
#
# Prompt: What are the official colors of the Pittsburgh Pirates?
# Generated Text: What are the official colors of the Pittsburgh Pirates? A: The official colors of the Pittsburgh Pirates are the vibrant gold, red, and blue, as well as the home colors of the Pittsburgh Black Band, the Pittsburgh Pride Parade, and the Pittsburgh Ill
#
# Prompt: What special event at the Warhol Museum on March 14, 2025, introduces the new director?
# Generated Text: What special event at the Warhol Museum on March 14, 2025, introduces the new director? A: The Warhol Museum will present "The Monuments Men," a new exhibition showcasing the world-class collection at the David L. Lawrence Convention Center
#
# Prompt: When will the The Pittsburgh Record Convention Spring Show 2025 be held?
# Generated Text: When will the The Pittsburgh Record Convention Spring Show 2025 be held? A: The Pittsburgh Record Convention Spring Show 2025 is scheduled for April 27-30, 2025. Q: What is the contact number for the ReelAbilities Pittsburgh Reel Summit 2025
#
# Prompt: What is the setting of "THe Height of Land" by M. C. Benner Dixon?
# Generated Text: What is the setting of "THe Height of Land" by M. C. Benner Dixon? A: The setting of "TThe Height of Land" is set against the city of Pittsburgh, PA, which has been in decline for over
#
# Prompt: Who wrote the play "Trouble in Mind"?
# Generated Text: Who wrote the play "Trouble in Mind"? A: Ryn Wisner, the playwright best known for his short stories, is considered one of Broadway's most influential people, with an excellent list compiled by the David L. Lawrence Conserv
#
# Prompt: Which Pittsburgh museum focuses on the gilded age and offers free admissions?
# Generated Text: Which Pittsburgh museum focuses on the gilded age and offers free admissions? A: Yes, the Museum of Illusions Pittsburgh offers free admission to select tour operators, as well as complimentary admission to the Mac & Cheese Festival. Q: What is significant about
#
# Prompt: What is the location for Sweaty Already String Band's performances?
# Generated Text: What is the location for Sweaty Already String Band's performances? A: The location is South Side Stage AE, just east of The Fort and Broadway. Q: What kind of performances are there planned for the tour? A: There are various
#
# Prompt: What are the five competitive categories for booth?
# Generated Text: What are the five competitive categories for booth? A: The five competitive categories are: Accessibility, Business Applications, Marketing Services, Marketing Priorities, and Transportation. Q: What kind of experiences can I find in Pittsburgh? A: Pittsburgh offers a
#
# Prompt: Who directed the CMU drama "The Inseparables"?
# Generated Text: Who directed the CMU drama "The Inseparables"? A: Joseph Campbell was the showrunner on the show and Barry Manilow was also on board as the showrunner. Q: What was the original purpose of the teaser for "The
#
# Prompt: Which puppeteer collaborated on STAND BY — an allegory?
# Generated Text: Which puppeteer collaborated on STAND BY — an allegory? A: Theatergoers thought that Kennywood's monologue about the importance of families and their faith was monotonous, while the playwright was interested in themes such as personal and
#
# Prompt: What type of play is Alice Childress’ "Trouble in Mind"?
# Generated Text: What type of play is Alice Childress’ "Trouble in Mind"? A: "This Is Trouble in Mind" is a six-part musical set against the vibrant cityscape, featuring diverse characters and songs. Q: When was the
#
# Prompt: Which app is mentioned for MLB ballpark experiences?
# Generated Text: Which app is mentioned for MLB ballpark experiences? A: The app mentions there are various toolkits and resources available for exploring various MLB stadiums, which can be found in the ConnectedPlanner app. Q: Can you mention any specific concerts scheduled
#
# Prompt: Where is the Pittsburgh Downtown Partnership located?
# Generated Text: Where is the Pittsburgh Downtown Partnership located? A: The Pittsburgh Downtown Partnership, founded in 1990, has become one of Pittsburgh's largest hotel brands, providing local suppliers with better-equipped hotels and resorts throughout the region.
# Q: What are some activities
#
# Prompt: What event will take place at the Bitz Opera Factory on April 12, 2025, from 12:00 PM to 01:00 PM?
# Generated Text: What event will take place at the Bitz Opera Factory on April 12, 2025, from 12:00 PM to 01:00 PM? A: The Bitz Opera Factory is the largest concert series in Pittsburgh, showcasing the music and artistry of
#
# Prompt: Which museum in Pittsburgh allows visitors to experience interactive simulations of lunar missions?
# Generated Text: Which museum in Pittsburgh allows visitors to experience interactive simulations of lunar missions? A: The Pittsburgh Insiders Museum, which opened in early October, aims to immerse visitors in the historical and cultural offerings of the city, offering immersive experiences both romantic and
#
# Prompt: What year was the Pittsburgh Penguins team founded?
# Generated Text: What year was the Pittsburgh Penguins team founded? A: The Pittsburgh Penguins were founded in 1794. Q: Which team played in Pittsburgh before the Pittsburgh Steel Revolution? A: The Pittsburgh Steelers are the team composed of the Steel Knights (1927-
#
# Prompt: What can younger audiences expect to find at Pittsburgh's Children's Museum besides the waterplay area?
# Generated Text: What can younger audiences expect to find at Pittsburgh's Children's Museum besides the waterplay area? A: Visitors can expect charming looks at the Strip District, informative art exhibits, and child-friendly museums. Q: What unique tours are available to add
#
# Prompt: Who wrote the CMU drama "Mary-Kate Olsen Is in Love"?
# Generated Text: Who wrote the CMU drama "Mary-Kate Olsen Is in Love"? A: Joseph Campbell is best known for writing the "Miguel Muñoz In Love" and "Candlelight: Hickory and Joan Crawford in Disguise
#
# Prompt: Where is the South Side Soup Contest held?
# Generated Text: Where is the South Side Soup Contest held? A: The South Side Soup Contest is held on July 26, 2024, from 6 to 8 p.m. Q: Who is chosen as the host for the "Show Your Badge" event? A
#
# Prompt: What are the four main committees of Activities Board?
# Generated Text: What are the four main committees of Activities Board? A: The four main committees of Activities Board are the Business Events Team, Marketing Team, Health & Wellness Team, and Tourism Team. Q: What special focus does the Office of Public Works have
#
# Prompt: Who will CMU play against in softball on March 28, 2025?
# Generated Text: Who will CMU play against in softball on March 28, 2025? A: Couples can expect a game against one of the nation's top teams, which will determine the team's identity. Q: What can fans expect at Heinz Field
#
# Prompt: What is the location of The Band Jam festival?
# Generated Text: What is the location of The Band Jam festival? A: The Band Jam festival is scheduled for July 28-30, 2024, at the David L. Lawrence Convention Center, Pittsburgh, Pennsylvania. Q: What activities will be included in the Live Music
#
# Prompt: Who created the Terrible Towel?
# Generated Text: Who created the Terrible Towel? A: Andy Warhol founded Campbell's Soup Factory in 1935, where he marries Rosemary Palmer, the daughter of a prominent Senator John Heinz History Center patron. Q: What major league baseball teams are
#
# Prompt: What does the Carnegie Library of Pittsburgh offer across its 19 branches?
# Generated Text: What does the Carnegie Library of Pittsburgh offer across its 19 branches? A: The Carnegie Library of Pittsburgh offers a variety of services including digital media, archival materials, access to print collections, and the study of human experiences. Q: What major universities
#
# Prompt: What comedy tour will be at the Benedum Center on May 1, 2025?
# Generated Text: What comedy tour will be at the Benedum Center on May 1, 2025? A: The tour kicks off Comedy Central's monthly comedy tour, exploring several neighborhoods in Pittsburgh that have been transformed by the arrival of light rail and pedestrian traffic. Q:
#
# Prompt: What is the title of the program dedicated to connecting youth to football activities?
# Generated Text: What is the title of the program dedicated to connecting youth to football activities? A: The program, called YouthConnect, is designed to create a hub for exploring sports culture and enhancing student-athlete well-being.
# Q: What types of
#
# Prompt: Which event is known for showcasing over 30 kinds of mac and cheese?
# Generated Text: Which event is known for showcasing over 30 kinds of mac and cheese? A: The Top 10 Mac & Cheese Bonsai in the World series is an annual celebration in Pittsburgh where participants immerse themselves in mac and cheese concepts while showcasing their prowess
#
# Prompt: What special access do Gold Ticket holders receive at the Pittsburgh Taco Festival?
# Generated Text: What special access do Gold Ticket holders receive at the Pittsburgh Taco Festival? A: Members of the Gold Ticket Network receive complimentary hot dogs and fries at the Pittsburgh Taco Festival, along with complimentary beer and wine. Q: Who can travel with the Pittsburgh Taco
#
# Prompt: Which Pittsburgh food event features a competitive pickle juice drinking contest?
# Generated Text: Which Pittsburgh food event features a competitive pickle juice drinking contest? A: The Pickle Juice Drinking Contest is one of the few Pickle Juice Drinking Festivals in Pittsburgh, featuring local, national, and international beer enthusiasts competing for a limited-edition
#
# Prompt: Who is the Pirates player that won the World Series MVP in 1971?
# Generated Text: Who is the Pirates player that won the World Series MVP in 1971? A: Ross Detwiler is the Pirates' starting pitcher, who has started all 13 games and allowed 3 earned runs over his last four appearances. Q: Who has allowed more
#
# Prompt: What is the highlight food of the Fish Fry Season?
# Generated Text: What is the highlight food of the Fish Fry Season? A: The fish fry season features a variety of local favorites, including crab cakes, pierogies, homemade pierogies, pickles, and donuts. Q: What is the fish
#
# Prompt: Which month is known for Pittsburgh's maple festival events?
# Generated Text: Which month is known for Pittsburgh's maple festival events? A: The month is known for Pittsburgh's maple festivals, which take place in October and November. Q: What notable event is the Pittsburgh Hickory Festival? A: The Pittsburgh Hickory Festival
#
# Prompt: What is the main attraction of the South Side Soup Contest?
# Generated Text: What is the main attraction of the South Side Soup Contest? A: The main attraction is the South Side Soup Contest, where thousands of South Side Soup Contest winners are served hot dogs and cheese at various locations throughout the neighborhood. Q: What activities are
#
# Prompt: What food is Picklesburgh centered around?
# Generated Text: What food is Picklesburgh centered around? A: Picklesburgh is a Picklerian confectionery chain offering handcrafted jams and pops at various pickle-themed restaurants. Q: Where can you find the original name of Picklesburgh
#
# Prompt: Which exhibition will run at the Pittsburgh Cultural Trust from January 18 to June 1, 2025?
# Generated Text: Which exhibition will run at the Pittsburgh Cultural Trust from January 18 to June 1, 2025? A: The exhibition "Art on Tap: Pittsburgh's First Pusadee," runs from January 18 to June 1, 2025. Q: What new exhibition
#
# Prompt: What kind of food is featured in the Lenten Fish Fry?
# Generated Text: What kind of food is featured in the Lenten Fish Fry? A: For Lenten Fish Fry, the dish is prepared at the I Made It! Market, where I create unique dishes using hand-battered, pre-mixed meals adapted
#
# Prompt: To whom will the proceeds of the Code & Crematory 2025 event benefit?
# Generated Text: To whom will the proceeds of the Code & Crematory 2025 event benefit? A: The proceeds from the Code & Crematory 2025 will be used to pay for parking and medical travel for the communities in need.
# Q: What types of
#
# Prompt: What event will be hosted by Entertainment Technology Center and IDeATe students at CMU?
# Generated Text: What event will be hosted by Entertainment Technology Center and IDeATe students at CMU? A: The EDC will host a Sensory Friendly Home Dash at the Carnegie Mellon University Applied Physics Lab on May 26, 2024, in partnership with the
#
# Prompt: Which exhibition featuring Tatiana Bilbao Estudio will run from September 21, 2024, to June 15, 2025?
# Generated Text: Which exhibition featuring Tatiana Bilbao Estudio will run from September 21, 2024, to June 15, 2025? A: The exhibition "Tatiana Bilbao “Estudio: First Fridays at the Pavilion at the Light
#
# Prompt: What year was Pittsburgh officially recognized as a city?
# Generated Text: What year was Pittsburgh officially recognized as a city? A: Pittsburgh was officially designated as a city on April 16, 1816. Q: What notable event took place on April 12, 1816, in relation to Pittsburgh? A: On April 12
#
# Prompt: When will the Pittsburgh Vegan Expo & Festival take place in 2024?
# Generated Text: When will the Pittsburgh Vegan Expo & Festival take place in 2024? A: The Pittsburgh Vegan Expo & Festival will take place in 2024, running from November 15-21, 2024. Q: What special event is being hosted by the Pittsburgh Vegan Expo &
#
# Prompt: What gift do you get if you sign up for a membership with Pittsburgh City Paper?
# Generated Text: What gift do you get if you sign up for a membership with Pittsburgh City Paper? A: Members get to pick ten unique products from the MailPITTSBURGH collection and can receive a one-of-a-kind hoodie, pens
#
# Prompt: What type of artworks can one explore at The Andy Warhol Museum in Pittsburgh?
# Generated Text: What type of artworks can one explore at The Andy Warhol Museum in Pittsburgh? A: Pittsburgh offers a collection of extraordinary murals and engravings, including the Andy Warhol Museum's iconic piece "The Monuments Menagerie." Q:
